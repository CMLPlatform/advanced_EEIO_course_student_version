# %% [markdown]
# # Mock mid-term exam: April 2023
#
# The objectives of this mock mid-term exam are:
# - to gain acquaintance with the type of programming questions that you will be asked during the mid-term exam
# - Becoming more comfortable in performing Input-Output analysis calculations
#
# We are accounting that you will need around 100-120 minutes to complete the assignment
#
# Please ensure that you run each cell (ctrl+enter) so that your inputs are saved
#
# All questions have either coding cell or a text cell, or a combination of the two.
#
# You are allowed to create additional cells for each answer to facilitate your work

# %% [markdown]
# ## Data preparation: Download and import exiobase data - year 2015, industry-by-industry format

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import here your data
path = "data/IOT_2015_ixi/"
A = pd.read_csv(f'{path}A.txt', sep='\t', index_col=[0, 1], header=[0, 1])
Y = pd.read_csv(f'{path}Y.txt' , sep='\t', index_col=[0, 1], header=[0, 1])

# Import satellite accounts
F_sat = pd.read_csv(f'{path}satellite/F.txt' , sep='\t', index_col=[0], header=[0, 1])
F_sat_hh = pd.read_csv(f'{path}satellite/F_y.txt' , sep='\t', index_col=[0], header=[0, 1])

# %%
print(*A.index, sep="\n")
# Out:
# ('AT', 'Cultivation of paddy rice')
# ('AT', 'Cultivation of wheat')
# ('AT', 'Cultivation of cereal grains nec')
# ('AT', 'Cultivation of vegetables, fruit, nuts')
# ('AT', 'Cultivation of oil seeds')
# ('AT', 'Cultivation of sugar cane, sugar beet')
# ('AT', 'Cultivation of plant-based fibers')
# ('AT', 'Cultivation of crops nec')
# ('AT', 'Cattle farming')
# ('AT', 'Pigs farming')
# ('AT', 'Poultry farming')
# ('AT', 'Meat animals nec')
# ('AT', 'Animal products nec')
# ('AT', 'Raw milk')
# ('AT', 'Wool, silk-worm cocoons')
# ('AT', 'Manure treatment (conventional), storage and land application')
# ('AT', 'Manure treatment (biogas), storage and land application')
# ('AT', 'Forestry, logging and related service activities (02)')
# ('AT', 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)')
# ('AT', 'Mining of coal and lignite; extraction of peat (10)')
# ('AT', 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying')
# ('AT', 'Extraction of natural gas and services related to natural gas extraction, excluding surveying')
# ('AT', 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials')
# ('AT', 'Mining of uranium and thorium ores (12)')
# ('AT', 'Mining of iron ores')
# ('AT', 'Mining of copper ores and concentrates')
# ('AT', 'Mining of nickel ores and concentrates')
# ('AT', 'Mining of aluminium ores and concentrates')
# ('AT', 'Mining of precious metal ores and concentrates')
# ('AT', 'Mining of lead, zinc and tin ores and concentrates')
# ('AT', 'Mining of other non-ferrous metal ores and concentrates')
# ('AT', 'Quarrying of stone')
# ('AT', 'Quarrying of sand and clay')
# ('AT', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('AT', 'Processing of meat cattle')
# ('AT', 'Processing of meat pigs')
# ('AT', 'Processing of meat poultry')
# ('AT', 'Production of meat products nec')
# ('AT', 'Processing vegetable oils and fats')
# ('AT', 'Processing of dairy products')
# ('AT', 'Processed rice')
# ('AT', 'Sugar refining')
# ('AT', 'Processing of Food products nec')
# ('AT', 'Manufacture of beverages')
# ('AT', 'Manufacture of fish products')
# ('AT', 'Manufacture of tobacco products (16)')
# ('AT', 'Manufacture of textiles (17)')
# ('AT', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('AT', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('AT', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('AT', 'Re-processing of secondary wood material into new wood material')
# ('AT', 'Pulp')
# ('AT', 'Re-processing of secondary paper into new pulp')
# ('AT', 'Paper')
# ('AT', 'Publishing, printing and reproduction of recorded media (22)')
# ('AT', 'Manufacture of coke oven products')
# ('AT', 'Petroleum Refinery')
# ('AT', 'Processing of nuclear fuel')
# ('AT', 'Plastics, basic')
# ('AT', 'Re-processing of secondary plastic into new plastic')
# ('AT', 'N-fertiliser')
# ('AT', 'P- and other fertiliser')
# ('AT', 'Chemicals nec')
# ('AT', 'Manufacture of rubber and plastic products (25)')
# ('AT', 'Manufacture of glass and glass products')
# ('AT', 'Re-processing of secondary glass into new glass')
# ('AT', 'Manufacture of ceramic goods')
# ('AT', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('AT', 'Manufacture of cement, lime and plaster')
# ('AT', 'Re-processing of ash into clinker')
# ('AT', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('AT', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('AT', 'Re-processing of secondary steel into new steel')
# ('AT', 'Precious metals production')
# ('AT', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('AT', 'Aluminium production')
# ('AT', 'Re-processing of secondary aluminium into new aluminium')
# ('AT', 'Lead, zinc and tin production')
# ('AT', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('AT', 'Copper production')
# ('AT', 'Re-processing of secondary copper into new copper')
# ('AT', 'Other non-ferrous metal production')
# ('AT', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('AT', 'Casting of metals')
# ('AT', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('AT', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('AT', 'Manufacture of office machinery and computers (30)')
# ('AT', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('AT', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('AT', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('AT', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('AT', 'Manufacture of other transport equipment (35)')
# ('AT', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('AT', 'Recycling of waste and scrap')
# ('AT', 'Recycling of bottles by direct reuse')
# ('AT', 'Production of electricity by coal')
# ('AT', 'Production of electricity by gas')
# ('AT', 'Production of electricity by nuclear')
# ('AT', 'Production of electricity by hydro')
# ('AT', 'Production of electricity by wind')
# ('AT', 'Production of electricity by petroleum and other oil derivatives')
# ('AT', 'Production of electricity by biomass and waste')
# ('AT', 'Production of electricity by solar photovoltaic')
# ('AT', 'Production of electricity by solar thermal')
# ('AT', 'Production of electricity by tide, wave, ocean')
# ('AT', 'Production of electricity by Geothermal')
# ('AT', 'Production of electricity nec')
# ('AT', 'Transmission of electricity')
# ('AT', 'Distribution and trade of electricity')
# ('AT', 'Manufacture of gas; distribution of gaseous fuels through mains')
# ('AT', 'Steam and hot water supply')
# ('AT', 'Collection, purification and distribution of water (41)')
# ('AT', 'Construction (45)')
# ('AT', 'Re-processing of secondary construction material into aggregates')
# ('AT', 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries')
# ('AT', 'Retail sale of automotive fuel')
# ('AT', 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)')
# ('AT', 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)')
# ('AT', 'Hotels and restaurants (55)')
# ('AT', 'Transport via railways')
# ('AT', 'Other land transport')
# ('AT', 'Transport via pipelines')
# ('AT', 'Sea and coastal water transport')
# ('AT', 'Inland water transport')
# ('AT', 'Air transport (62)')
# ('AT', 'Supporting and auxiliary transport activities; activities of travel agencies (63)')
# ('AT', 'Post and telecommunications (64)')
# ('AT', 'Financial intermediation, except insurance and pension funding (65)')
# ('AT', 'Insurance and pension funding, except compulsory social security (66)')
# ('AT', 'Activities auxiliary to financial intermediation (67)')
# ('AT', 'Real estate activities (70)')
# ('AT', 'Renting of machinery and equipment without operator and of personal and household goods (71)')
# ('AT', 'Computer and related activities (72)')
# ('AT', 'Research and development (73)')
# ('AT', 'Other business activities (74)')
# ('AT', 'Public administration and defence; compulsory social security (75)')
# ('AT', 'Education (80)')
# ('AT', 'Health and social work (85)')
# ('AT', 'Incineration of waste: Food')
# ('AT', 'Incineration of waste: Paper')
# ('AT', 'Incineration of waste: Plastic')
# ('AT', 'Incineration of waste: Metals and Inert materials')
# ('AT', 'Incineration of waste: Textiles')
# ('AT', 'Incineration of waste: Wood')
# ('AT', 'Incineration of waste: Oil/Hazardous waste')
# ('AT', 'Biogasification of food waste, incl. land application')
# ('AT', 'Biogasification of paper, incl. land application')
# ('AT', 'Biogasification of sewage slugde, incl. land application')
# ('AT', 'Composting of food waste, incl. land application')
# ('AT', 'Composting of paper and wood, incl. land application')
# ('AT', 'Waste water treatment, food')
# ('AT', 'Waste water treatment, other')
# ('AT', 'Landfill of waste: Food')
# ('AT', 'Landfill of waste: Paper')
# ('AT', 'Landfill of waste: Plastic')
# ('AT', 'Landfill of waste: Inert/metal/hazardous')
# ('AT', 'Landfill of waste: Textiles')
# ('AT', 'Landfill of waste: Wood')
# ('AT', 'Activities of membership organisation n.e.c. (91)')
# ('AT', 'Recreational, cultural and sporting activities (92)')
# ('AT', 'Other service activities (93)')
# ('AT', 'Private households with employed persons (95)')
# ('AT', 'Extra-territorial organizations and bodies')
# ('BE', 'Cultivation of paddy rice')
# ('BE', 'Cultivation of wheat')
# ('BE', 'Cultivation of cereal grains nec')
# ('BE', 'Cultivation of vegetables, fruit, nuts')
# ('BE', 'Cultivation of oil seeds')
# ('BE', 'Cultivation of sugar cane, sugar beet')
# ('BE', 'Cultivation of plant-based fibers')
# ('BE', 'Cultivation of crops nec')
# ('BE', 'Cattle farming')
# ('BE', 'Pigs farming')
# ('BE', 'Poultry farming')
# ('BE', 'Meat animals nec')
# ('BE', 'Animal products nec')
# ('BE', 'Raw milk')
# ('BE', 'Wool, silk-worm cocoons')
# ('BE', 'Manure treatment (conventional), storage and land application')
# ('BE', 'Manure treatment (biogas), storage and land application')
# ('BE', 'Forestry, logging and related service activities (02)')
# ('BE', 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)')
# ('BE', 'Mining of coal and lignite; extraction of peat (10)')
# ('BE', 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying')
# ('BE', 'Extraction of natural gas and services related to natural gas extraction, excluding surveying')
# ('BE', 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials')
# ('BE', 'Mining of uranium and thorium ores (12)')
# ('BE', 'Mining of iron ores')
# ('BE', 'Mining of copper ores and concentrates')
# ('BE', 'Mining of nickel ores and concentrates')
# ('BE', 'Mining of aluminium ores and concentrates')
# ('BE', 'Mining of precious metal ores and concentrates')
# ('BE', 'Mining of lead, zinc and tin ores and concentrates')
# ('BE', 'Mining of other non-ferrous metal ores and concentrates')
# ('BE', 'Quarrying of stone')
# ('BE', 'Quarrying of sand and clay')
# ('BE', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('BE', 'Processing of meat cattle')
# ('BE', 'Processing of meat pigs')
# ('BE', 'Processing of meat poultry')
# ('BE', 'Production of meat products nec')
# ('BE', 'Processing vegetable oils and fats')
# ('BE', 'Processing of dairy products')
# ('BE', 'Processed rice')
# ('BE', 'Sugar refining')
# ('BE', 'Processing of Food products nec')
# ('BE', 'Manufacture of beverages')
# ('BE', 'Manufacture of fish products')
# ('BE', 'Manufacture of tobacco products (16)')
# ('BE', 'Manufacture of textiles (17)')
# ('BE', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('BE', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('BE', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('BE', 'Re-processing of secondary wood material into new wood material')
# ('BE', 'Pulp')
# ('BE', 'Re-processing of secondary paper into new pulp')
# ('BE', 'Paper')
# ('BE', 'Publishing, printing and reproduction of recorded media (22)')
# ('BE', 'Manufacture of coke oven products')
# ('BE', 'Petroleum Refinery')
# ('BE', 'Processing of nuclear fuel')
# ('BE', 'Plastics, basic')
# ('BE', 'Re-processing of secondary plastic into new plastic')
# ('BE', 'N-fertiliser')
# ('BE', 'P- and other fertiliser')
# ('BE', 'Chemicals nec')
# ('BE', 'Manufacture of rubber and plastic products (25)')
# ('BE', 'Manufacture of glass and glass products')
# ('BE', 'Re-processing of secondary glass into new glass')
# ('BE', 'Manufacture of ceramic goods')
# ('BE', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('BE', 'Manufacture of cement, lime and plaster')
# ('BE', 'Re-processing of ash into clinker')
# ('BE', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('BE', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('BE', 'Re-processing of secondary steel into new steel')
# ('BE', 'Precious metals production')
# ('BE', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('BE', 'Aluminium production')
# ('BE', 'Re-processing of secondary aluminium into new aluminium')
# ('BE', 'Lead, zinc and tin production')
# ('BE', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('BE', 'Copper production')
# ('BE', 'Re-processing of secondary copper into new copper')
# ('BE', 'Other non-ferrous metal production')
# ('BE', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('BE', 'Casting of metals')
# ('BE', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('BE', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('BE', 'Manufacture of office machinery and computers (30)')
# ('BE', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('BE', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('BE', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('BE', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('BE', 'Manufacture of other transport equipment (35)')
# ('BE', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('BE', 'Recycling of waste and scrap')
# ('BE', 'Recycling of bottles by direct reuse')
# ('BE', 'Production of electricity by coal')
# ('BE', 'Production of electricity by gas')
# ('BE', 'Production of electricity by nuclear')
# ('BE', 'Production of electricity by hydro')
# ('BE', 'Production of electricity by wind')
# ('BE', 'Production of electricity by petroleum and other oil derivatives')
# ('BE', 'Production of electricity by biomass and waste')
# ('BE', 'Production of electricity by solar photovoltaic')
# ('BE', 'Production of electricity by solar thermal')
# ('BE', 'Production of electricity by tide, wave, ocean')
# ('BE', 'Production of electricity by Geothermal')
# ('BE', 'Production of electricity nec')
# ('BE', 'Transmission of electricity')
# ('BE', 'Distribution and trade of electricity')
# ('BE', 'Manufacture of gas; distribution of gaseous fuels through mains')
# ('BE', 'Steam and hot water supply')
# ('BE', 'Collection, purification and distribution of water (41)')
# ('BE', 'Construction (45)')
# ('BE', 'Re-processing of secondary construction material into aggregates')
# ('BE', 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries')
# ('BE', 'Retail sale of automotive fuel')
# ('BE', 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)')
# ('BE', 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)')
# ('BE', 'Hotels and restaurants (55)')
# ('BE', 'Transport via railways')
# ('BE', 'Other land transport')
# ('BE', 'Transport via pipelines')
# ('BE', 'Sea and coastal water transport')
# ('BE', 'Inland water transport')
# ('BE', 'Air transport (62)')
# ('BE', 'Supporting and auxiliary transport activities; activities of travel agencies (63)')
# ('BE', 'Post and telecommunications (64)')
# ('BE', 'Financial intermediation, except insurance and pension funding (65)')
# ('BE', 'Insurance and pension funding, except compulsory social security (66)')
# ('BE', 'Activities auxiliary to financial intermediation (67)')
# ('BE', 'Real estate activities (70)')
# ('BE', 'Renting of machinery and equipment without operator and of personal and household goods (71)')
# ('BE', 'Computer and related activities (72)')
# ('BE', 'Research and development (73)')
# ('BE', 'Other business activities (74)')
# ('BE', 'Public administration and defence; compulsory social security (75)')
# ('BE', 'Education (80)')
# ('BE', 'Health and social work (85)')
# ('BE', 'Incineration of waste: Food')
# ('BE', 'Incineration of waste: Paper')
# ('BE', 'Incineration of waste: Plastic')
# ('BE', 'Incineration of waste: Metals and Inert materials')
# ('BE', 'Incineration of waste: Textiles')
# ('BE', 'Incineration of waste: Wood')
# ('BE', 'Incineration of waste: Oil/Hazardous waste')
# ('BE', 'Biogasification of food waste, incl. land application')
# ('BE', 'Biogasification of paper, incl. land application')
# ('BE', 'Biogasification of sewage slugde, incl. land application')
# ('BE', 'Composting of food waste, incl. land application')
# ('BE', 'Composting of paper and wood, incl. land application')
# ('BE', 'Waste water treatment, food')
# ('BE', 'Waste water treatment, other')
# ('BE', 'Landfill of waste: Food')
# ('BE', 'Landfill of waste: Paper')
# ('BE', 'Landfill of waste: Plastic')
# ('BE', 'Landfill of waste: Inert/metal/hazardous')
# ('BE', 'Landfill of waste: Textiles')
# ('BE', 'Landfill of waste: Wood')
# ('BE', 'Activities of membership organisation n.e.c. (91)')
# ('BE', 'Recreational, cultural and sporting activities (92)')
# ('BE', 'Other service activities (93)')
# ('BE', 'Private households with employed persons (95)')
# ('BE', 'Extra-territorial organizations and bodies')
# ('BG', 'Cultivation of paddy rice')
# ('BG', 'Cultivation of wheat')
# ('BG', 'Cultivation of cereal grains nec')
# ('BG', 'Cultivation of vegetables, fruit, nuts')
# ('BG', 'Cultivation of oil seeds')
# ('BG', 'Cultivation of sugar cane, sugar beet')
# ('BG', 'Cultivation of plant-based fibers')
# ('BG', 'Cultivation of crops nec')
# ('BG', 'Cattle farming')
# ('BG', 'Pigs farming')
# ('BG', 'Poultry farming')
# ('BG', 'Meat animals nec')
# ('BG', 'Animal products nec')
# ('BG', 'Raw milk')
# ('BG', 'Wool, silk-worm cocoons')
# ('BG', 'Manure treatment (conventional), storage and land application')
# ('BG', 'Manure treatment (biogas), storage and land application')
# ('BG', 'Forestry, logging and related service activities (02)')
# ('BG', 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)')
# ('BG', 'Mining of coal and lignite; extraction of peat (10)')
# ('BG', 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying')
# ('BG', 'Extraction of natural gas and services related to natural gas extraction, excluding surveying')
# ('BG', 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials')
# ('BG', 'Mining of uranium and thorium ores (12)')
# ('BG', 'Mining of iron ores')
# ('BG', 'Mining of copper ores and concentrates')
# ('BG', 'Mining of nickel ores and concentrates')
# ('BG', 'Mining of aluminium ores and concentrates')
# ('BG', 'Mining of precious metal ores and concentrates')
# ('BG', 'Mining of lead, zinc and tin ores and concentrates')
# ('BG', 'Mining of other non-ferrous metal ores and concentrates')
# ('BG', 'Quarrying of stone')
# ('BG', 'Quarrying of sand and clay')
# ('BG', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('BG', 'Processing of meat cattle')
# ('BG', 'Processing of meat pigs')
# ('BG', 'Processing of meat poultry')
# ('BG', 'Production of meat products nec')
# ('BG', 'Processing vegetable oils and fats')
# ('BG', 'Processing of dairy products')
# ('BG', 'Processed rice')
# ('BG', 'Sugar refining')
# ('BG', 'Processing of Food products nec')
# ('BG', 'Manufacture of beverages')
# ('BG', 'Manufacture of fish products')
# ('BG', 'Manufacture of tobacco products (16)')
# ('BG', 'Manufacture of textiles (17)')
# ('BG', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('BG', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('BG', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('BG', 'Re-processing of secondary wood material into new wood material')
# ('BG', 'Pulp')
# ('BG', 'Re-processing of secondary paper into new pulp')
# ('BG', 'Paper')
# ('BG', 'Publishing, printing and reproduction of recorded media (22)')
# ('BG', 'Manufacture of coke oven products')
# ('BG', 'Petroleum Refinery')
# ('BG', 'Processing of nuclear fuel')
# ('BG', 'Plastics, basic')
# ('BG', 'Re-processing of secondary plastic into new plastic')
# ('BG', 'N-fertiliser')
# ('BG', 'P- and other fertiliser')
# ('BG', 'Chemicals nec')
# ('BG', 'Manufacture of rubber and plastic products (25)')
# ('BG', 'Manufacture of glass and glass products')
# ('BG', 'Re-processing of secondary glass into new glass')
# ('BG', 'Manufacture of ceramic goods')
# ('BG', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('BG', 'Manufacture of cement, lime and plaster')
# ('BG', 'Re-processing of ash into clinker')
# ('BG', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('BG', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('BG', 'Re-processing of secondary steel into new steel')
# ('BG', 'Precious metals production')
# ('BG', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('BG', 'Aluminium production')
# ('BG', 'Re-processing of secondary aluminium into new aluminium')
# ('BG', 'Lead, zinc and tin production')
# ('BG', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('BG', 'Copper production')
# ('BG', 'Re-processing of secondary copper into new copper')
# ('BG', 'Other non-ferrous metal production')
# ('BG', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('BG', 'Casting of metals')
# ('BG', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('BG', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('BG', 'Manufacture of office machinery and computers (30)')
# ('BG', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('BG', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('BG', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('BG', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('BG', 'Manufacture of other transport equipment (35)')
# ('BG', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('BG', 'Recycling of waste and scrap')
# ('BG', 'Recycling of bottles by direct reuse')
# ('BG', 'Production of electricity by coal')
# ('BG', 'Production of electricity by gas')
# ('BG', 'Production of electricity by nuclear')
# ('BG', 'Production of electricity by hydro')
# ('BG', 'Production of electricity by wind')
# ('BG', 'Production of electricity by petroleum and other oil derivatives')
# ('BG', 'Production of electricity by biomass and waste')
# ('BG', 'Production of electricity by solar photovoltaic')
# ('BG', 'Production of electricity by solar thermal')
# ('BG', 'Production of electricity by tide, wave, ocean')
# ('BG', 'Production of electricity by Geothermal')
# ('BG', 'Production of electricity nec')
# ('BG', 'Transmission of electricity')
# ('BG', 'Distribution and trade of electricity')
# ('BG', 'Manufacture of gas; distribution of gaseous fuels through mains')
# ('BG', 'Steam and hot water supply')
# ('BG', 'Collection, purification and distribution of water (41)')
# ('BG', 'Construction (45)')
# ('BG', 'Re-processing of secondary construction material into aggregates')
# ('BG', 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries')
# ('BG', 'Retail sale of automotive fuel')
# ('BG', 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)')
# ('BG', 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)')
# ('BG', 'Hotels and restaurants (55)')
# ('BG', 'Transport via railways')
# ('BG', 'Other land transport')
# ('BG', 'Transport via pipelines')
# ('BG', 'Sea and coastal water transport')
# ('BG', 'Inland water transport')
# ('BG', 'Air transport (62)')
# ('BG', 'Supporting and auxiliary transport activities; activities of travel agencies (63)')
# ('BG', 'Post and telecommunications (64)')
# ('BG', 'Financial intermediation, except insurance and pension funding (65)')
# ('BG', 'Insurance and pension funding, except compulsory social security (66)')
# ('BG', 'Activities auxiliary to financial intermediation (67)')
# ('BG', 'Real estate activities (70)')
# ('BG', 'Renting of machinery and equipment without operator and of personal and household goods (71)')
# ('BG', 'Computer and related activities (72)')
# ('BG', 'Research and development (73)')
# ('BG', 'Other business activities (74)')
# ('BG', 'Public administration and defence; compulsory social security (75)')
# ('BG', 'Education (80)')
# ('BG', 'Health and social work (85)')
# ('BG', 'Incineration of waste: Food')
# ('BG', 'Incineration of waste: Paper')
# ('BG', 'Incineration of waste: Plastic')
# ('BG', 'Incineration of waste: Metals and Inert materials')
# ('BG', 'Incineration of waste: Textiles')
# ('BG', 'Incineration of waste: Wood')
# ('BG', 'Incineration of waste: Oil/Hazardous waste')
# ('BG', 'Biogasification of food waste, incl. land application')
# ('BG', 'Biogasification of paper, incl. land application')
# ('BG', 'Biogasification of sewage slugde, incl. land application')
# ('BG', 'Composting of food waste, incl. land application')
# ('BG', 'Composting of paper and wood, incl. land application')
# ('BG', 'Waste water treatment, food')
# ('BG', 'Waste water treatment, other')
# ('BG', 'Landfill of waste: Food')
# ('BG', 'Landfill of waste: Paper')
# ('BG', 'Landfill of waste: Plastic')
# ('BG', 'Landfill of waste: Inert/metal/hazardous')
# ('BG', 'Landfill of waste: Textiles')
# ('BG', 'Landfill of waste: Wood')
# ('BG', 'Activities of membership organisation n.e.c. (91)')
# ('BG', 'Recreational, cultural and sporting activities (92)')
# ('BG', 'Other service activities (93)')
# ('BG', 'Private households with employed persons (95)')
# ('BG', 'Extra-territorial organizations and bodies')
# ('CY', 'Cultivation of paddy rice')
# ('CY', 'Cultivation of wheat')
# ('CY', 'Cultivation of cereal grains nec')
# ('CY', 'Cultivation of vegetables, fruit, nuts')
# ('CY', 'Cultivation of oil seeds')
# ('CY', 'Cultivation of sugar cane, sugar beet')
# ('CY', 'Cultivation of plant-based fibers')
# ('CY', 'Cultivation of crops nec')
# ('CY', 'Cattle farming')
# ('CY', 'Pigs farming')
# ('CY', 'Poultry farming')
# ('CY', 'Meat animals nec')
# ('CY', 'Animal products nec')
# ('CY', 'Raw milk')
# ('CY', 'Wool, silk-worm cocoons')
# ('CY', 'Manure treatment (conventional), storage and land application')
# ('CY', 'Manure treatment (biogas), storage and land application')
# ('CY', 'Forestry, logging and related service activities (02)')
# ('CY', 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)')
# ('CY', 'Mining of coal and lignite; extraction of peat (10)')
# ('CY', 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying')
# ('CY', 'Extraction of natural gas and services related to natural gas extraction, excluding surveying')
# ('CY', 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials')
# ('CY', 'Mining of uranium and thorium ores (12)')
# ('CY', 'Mining of iron ores')
# ('CY', 'Mining of copper ores and concentrates')
# ('CY', 'Mining of nickel ores and concentrates')
# ('CY', 'Mining of aluminium ores and concentrates')
# ('CY', 'Mining of precious metal ores and concentrates')
# ('CY', 'Mining of lead, zinc and tin ores and concentrates')
# ('CY', 'Mining of other non-ferrous metal ores and concentrates')
# ('CY', 'Quarrying of stone')
# ('CY', 'Quarrying of sand and clay')
# ('CY', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('CY', 'Processing of meat cattle')
# ('CY', 'Processing of meat pigs')
# ('CY', 'Processing of meat poultry')
# ('CY', 'Production of meat products nec')
# ('CY', 'Processing vegetable oils and fats')
# ('CY', 'Processing of dairy products')
# ('CY', 'Processed rice')
# ('CY', 'Sugar refining')
# ('CY', 'Processing of Food products nec')
# ('CY', 'Manufacture of beverages')
# ('CY', 'Manufacture of fish products')
# ('CY', 'Manufacture of tobacco products (16)')
# ('CY', 'Manufacture of textiles (17)')
# ('CY', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('CY', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('CY', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('CY', 'Re-processing of secondary wood material into new wood material')
# ('CY', 'Pulp')
# ('CY', 'Re-processing of secondary paper into new pulp')
# ('CY', 'Paper')
# ('CY', 'Publishing, printing and reproduction of recorded media (22)')
# ('CY', 'Manufacture of coke oven products')
# ('CY', 'Petroleum Refinery')
# ('CY', 'Processing of nuclear fuel')
# ('CY', 'Plastics, basic')
# ('CY', 'Re-processing of secondary plastic into new plastic')
# ('CY', 'N-fertiliser')
# ('CY', 'P- and other fertiliser')
# ('CY', 'Chemicals nec')
# ('CY', 'Manufacture of rubber and plastic products (25)')
# ('CY', 'Manufacture of glass and glass products')
# ('CY', 'Re-processing of secondary glass into new glass')
# ('CY', 'Manufacture of ceramic goods')
# ('CY', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('CY', 'Manufacture of cement, lime and plaster')
# ('CY', 'Re-processing of ash into clinker')
# ('CY', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('CY', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('CY', 'Re-processing of secondary steel into new steel')
# ('CY', 'Precious metals production')
# ('CY', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('CY', 'Aluminium production')
# ('CY', 'Re-processing of secondary aluminium into new aluminium')
# ('CY', 'Lead, zinc and tin production')
# ('CY', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('CY', 'Copper production')
# ('CY', 'Re-processing of secondary copper into new copper')
# ('CY', 'Other non-ferrous metal production')
# ('CY', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('CY', 'Casting of metals')
# ('CY', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('CY', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('CY', 'Manufacture of office machinery and computers (30)')
# ('CY', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('CY', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('CY', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('CY', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('CY', 'Manufacture of other transport equipment (35)')
# ('CY', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('CY', 'Recycling of waste and scrap')
# ('CY', 'Recycling of bottles by direct reuse')
# ('CY', 'Production of electricity by coal')
# ('CY', 'Production of electricity by gas')
# ('CY', 'Production of electricity by nuclear')
# ('CY', 'Production of electricity by hydro')
# ('CY', 'Production of electricity by wind')
# ('CY', 'Production of electricity by petroleum and other oil derivatives')
# ('CY', 'Production of electricity by biomass and waste')
# ('CY', 'Production of electricity by solar photovoltaic')
# ('CY', 'Production of electricity by solar thermal')
# ('CY', 'Production of electricity by tide, wave, ocean')
# ('CY', 'Production of electricity by Geothermal')
# ('CY', 'Production of electricity nec')
# ('CY', 'Transmission of electricity')
# ('CY', 'Distribution and trade of electricity')
# ('CY', 'Manufacture of gas; distribution of gaseous fuels through mains')
# ('CY', 'Steam and hot water supply')
# ('CY', 'Collection, purification and distribution of water (41)')
# ('CY', 'Construction (45)')
# ('CY', 'Re-processing of secondary construction material into aggregates')
# ('CY', 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries')
# ('CY', 'Retail sale of automotive fuel')
# ('CY', 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)')
# ('CY', 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)')
# ('CY', 'Hotels and restaurants (55)')
# ('CY', 'Transport via railways')
# ('CY', 'Other land transport')
# ('CY', 'Transport via pipelines')
# ('CY', 'Sea and coastal water transport')
# ('CY', 'Inland water transport')
# ('CY', 'Air transport (62)')
# ('CY', 'Supporting and auxiliary transport activities; activities of travel agencies (63)')
# ('CY', 'Post and telecommunications (64)')
# ('CY', 'Financial intermediation, except insurance and pension funding (65)')
# ('CY', 'Insurance and pension funding, except compulsory social security (66)')
# ('CY', 'Activities auxiliary to financial intermediation (67)')
# ('CY', 'Real estate activities (70)')
# ('CY', 'Renting of machinery and equipment without operator and of personal and household goods (71)')
# ('CY', 'Computer and related activities (72)')
# ('CY', 'Research and development (73)')
# ('CY', 'Other business activities (74)')
# ('CY', 'Public administration and defence; compulsory social security (75)')
# ('CY', 'Education (80)')
# ('CY', 'Health and social work (85)')
# ('CY', 'Incineration of waste: Food')
# ('CY', 'Incineration of waste: Paper')
# ('CY', 'Incineration of waste: Plastic')
# ('CY', 'Incineration of waste: Metals and Inert materials')
# ('CY', 'Incineration of waste: Textiles')
# ('CY', 'Incineration of waste: Wood')
# ('CY', 'Incineration of waste: Oil/Hazardous waste')
# ('CY', 'Biogasification of food waste, incl. land application')
# ('CY', 'Biogasification of paper, incl. land application')
# ('CY', 'Biogasification of sewage slugde, incl. land application')
# ('CY', 'Composting of food waste, incl. land application')
# ('CY', 'Composting of paper and wood, incl. land application')
# ('CY', 'Waste water treatment, food')
# ('CY', 'Waste water treatment, other')
# ('CY', 'Landfill of waste: Food')
# ('CY', 'Landfill of waste: Paper')
# ('CY', 'Landfill of waste: Plastic')
# ('CY', 'Landfill of waste: Inert/metal/hazardous')
# ('CY', 'Landfill of waste: Textiles')
# ('CY', 'Landfill of waste: Wood')
# ('CY', 'Activities of membership organisation n.e.c. (91)')
# ('CY', 'Recreational, cultural and sporting activities (92)')
# ('CY', 'Other service activities (93)')
# ('CY', 'Private households with employed persons (95)')
# ('CY', 'Extra-territorial organizations and bodies')
# ('CZ', 'Cultivation of paddy rice')
# ('CZ', 'Cultivation of wheat')
# ('CZ', 'Cultivation of cereal grains nec')
# ('CZ', 'Cultivation of vegetables, fruit, nuts')
# ('CZ', 'Cultivation of oil seeds')
# ('CZ', 'Cultivation of sugar cane, sugar beet')
# ('CZ', 'Cultivation of plant-based fibers')
# ('CZ', 'Cultivation of crops nec')
# ('CZ', 'Cattle farming')
# ('CZ', 'Pigs farming')
# ('CZ', 'Poultry farming')
# ('CZ', 'Meat animals nec')
# ('CZ', 'Animal products nec')
# ('CZ', 'Raw milk')
# ('CZ', 'Wool, silk-worm cocoons')
# ('CZ', 'Manure treatment (conventional), storage and land application')
# ('CZ', 'Manure treatment (biogas), storage and land application')
# ('CZ', 'Forestry, logging and related service activities (02)')
# ('CZ', 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)')
# ('CZ', 'Mining of coal and lignite; extraction of peat (10)')
# ('CZ', 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying')
# ('CZ', 'Extraction of natural gas and services related to natural gas extraction, excluding surveying')
# ('CZ', 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials')
# ('CZ', 'Mining of uranium and thorium ores (12)')
# ('CZ', 'Mining of iron ores')
# ('CZ', 'Mining of copper ores and concentrates')
# ('CZ', 'Mining of nickel ores and concentrates')
# ('CZ', 'Mining of aluminium ores and concentrates')
# ('CZ', 'Mining of precious metal ores and concentrates')
# ('CZ', 'Mining of lead, zinc and tin ores and concentrates')
# ('CZ', 'Mining of other non-ferrous metal ores and concentrates')
# ('CZ', 'Quarrying of stone')
# ('CZ', 'Quarrying of sand and clay')
# ('CZ', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('CZ', 'Processing of meat cattle')
# ('CZ', 'Processing of meat pigs')
# ('CZ', 'Processing of meat poultry')
# ('CZ', 'Production of meat products nec')
# ('CZ', 'Processing vegetable oils and fats')
# ('CZ', 'Processing of dairy products')
# ('CZ', 'Processed rice')
# ('CZ', 'Sugar refining')
# ('CZ', 'Processing of Food products nec')
# ('CZ', 'Manufacture of beverages')
# ('CZ', 'Manufacture of fish products')
# ('CZ', 'Manufacture of tobacco products (16)')
# ('CZ', 'Manufacture of textiles (17)')
# ('CZ', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('CZ', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('CZ', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('CZ', 'Re-processing of secondary wood material into new wood material')
# ('CZ', 'Pulp')
# ('CZ', 'Re-processing of secondary paper into new pulp')
# ('CZ', 'Paper')
# ('CZ', 'Publishing, printing and reproduction of recorded media (22)')
# ('CZ', 'Manufacture of coke oven products')
# ('CZ', 'Petroleum Refinery')
# ('CZ', 'Processing of nuclear fuel')
# ('CZ', 'Plastics, basic')
# ('CZ', 'Re-processing of secondary plastic into new plastic')
# ('CZ', 'N-fertiliser')
# ('CZ', 'P- and other fertiliser')
# ('CZ', 'Chemicals nec')
# ('CZ', 'Manufacture of rubber and plastic products (25)')
# ('CZ', 'Manufacture of glass and glass products')
# ('CZ', 'Re-processing of secondary glass into new glass')
# ('CZ', 'Manufacture of ceramic goods')
# ('CZ', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('CZ', 'Manufacture of cement, lime and plaster')
# ('CZ', 'Re-processing of ash into clinker')
# ('CZ', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('CZ', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('CZ', 'Re-processing of secondary steel into new steel')
# ('CZ', 'Precious metals production')
# ('CZ', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('CZ', 'Aluminium production')
# ('CZ', 'Re-processing of secondary aluminium into new aluminium')
# ('CZ', 'Lead, zinc and tin production')
# ('CZ', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('CZ', 'Copper production')
# ('CZ', 'Re-processing of secondary copper into new copper')
# ('CZ', 'Other non-ferrous metal production')
# ('CZ', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('CZ', 'Casting of metals')
# ('CZ', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('CZ', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('CZ', 'Manufacture of office machinery and computers (30)')
# ('CZ', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('CZ', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('CZ', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('CZ', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('CZ', 'Manufacture of other transport equipment (35)')
# ('CZ', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('CZ', 'Recycling of waste and scrap')
# ('CZ', 'Recycling of bottles by direct reuse')
# ('CZ', 'Production of electricity by coal')
# ('CZ', 'Production of electricity by gas')
# ('CZ', 'Production of electricity by nuclear')
# ('CZ', 'Production of electricity by hydro')
# ('CZ', 'Production of electricity by wind')
# ('CZ', 'Production of electricity by petroleum and other oil derivatives')
# ('CZ', 'Production of electricity by biomass and waste')
# ('CZ', 'Production of electricity by solar photovoltaic')
# ('CZ', 'Production of electricity by solar thermal')
# ('CZ', 'Production of electricity by tide, wave, ocean')
# ('CZ', 'Production of electricity by Geothermal')
# ('CZ', 'Production of electricity nec')
# ('CZ', 'Transmission of electricity')
# ('CZ', 'Distribution and trade of electricity')
# ('CZ', 'Manufacture of gas; distribution of gaseous fuels through mains')
# ('CZ', 'Steam and hot water supply')
# ('CZ', 'Collection, purification and distribution of water (41)')
# ('CZ', 'Construction (45)')
# ('CZ', 'Re-processing of secondary construction material into aggregates')
# ('CZ', 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries')
# ('CZ', 'Retail sale of automotive fuel')
# ('CZ', 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)')
# ('CZ', 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)')
# ('CZ', 'Hotels and restaurants (55)')
# ('CZ', 'Transport via railways')
# ('CZ', 'Other land transport')
# ('CZ', 'Transport via pipelines')
# ('CZ', 'Sea and coastal water transport')
# ('CZ', 'Inland water transport')
# ('CZ', 'Air transport (62)')
# ('CZ', 'Supporting and auxiliary transport activities; activities of travel agencies (63)')
# ('CZ', 'Post and telecommunications (64)')
# ('CZ', 'Financial intermediation, except insurance and pension funding (65)')
# ('CZ', 'Insurance and pension funding, except compulsory social security (66)')
# ('CZ', 'Activities auxiliary to financial intermediation (67)')
# ('CZ', 'Real estate activities (70)')
# ('CZ', 'Renting of machinery and equipment without operator and of personal and household goods (71)')
# ('CZ', 'Computer and related activities (72)')
# ('CZ', 'Research and development (73)')
# ('CZ', 'Other business activities (74)')
# ('CZ', 'Public administration and defence; compulsory social security (75)')
# ('CZ', 'Education (80)')
# ('CZ', 'Health and social work (85)')
# ('CZ', 'Incineration of waste: Food')
# ('CZ', 'Incineration of waste: Paper')
# ('CZ', 'Incineration of waste: Plastic')
# ('CZ', 'Incineration of waste: Metals and Inert materials')
# ('CZ', 'Incineration of waste: Textiles')
# ('CZ', 'Incineration of waste: Wood')
# ('CZ', 'Incineration of waste: Oil/Hazardous waste')
# ('CZ', 'Biogasification of food waste, incl. land application')
# ('CZ', 'Biogasification of paper, incl. land application')
# ('CZ', 'Biogasification of sewage slugde, incl. land application')
# ('CZ', 'Composting of food waste, incl. land application')
# ('CZ', 'Composting of paper and wood, incl. land application')
# ('CZ', 'Waste water treatment, food')
# ('CZ', 'Waste water treatment, other')
# ('CZ', 'Landfill of waste: Food')
# ('CZ', 'Landfill of waste: Paper')
# ('CZ', 'Landfill of waste: Plastic')
# ('CZ', 'Landfill of waste: Inert/metal/hazardous')
# ('CZ', 'Landfill of waste: Textiles')
# ('CZ', 'Landfill of waste: Wood')
# ('CZ', 'Activities of membership organisation n.e.c. (91)')
# ('CZ', 'Recreational, cultural and sporting activities (92)')
# ('CZ', 'Other service activities (93)')
# ('CZ', 'Private households with employed persons (95)')
# ('CZ', 'Extra-territorial organizations and bodies')
# ('DE', 'Cultivation of paddy rice')
# ('DE', 'Cultivation of wheat')
# ('DE', 'Cultivation of cereal grains nec')
# ('DE', 'Cultivation of vegetables, fruit, nuts')
# ('DE', 'Cultivation of oil seeds')
# ('DE', 'Cultivation of sugar cane, sugar beet')
# ('DE', 'Cultivation of plant-based fibers')
# ('DE', 'Cultivation of crops nec')
# ('DE', 'Cattle farming')
# ('DE', 'Pigs farming')
# ('DE', 'Poultry farming')
# ('DE', 'Meat animals nec')
# ('DE', 'Animal products nec')
# ('DE', 'Raw milk')
# ('DE', 'Wool, silk-worm cocoons')
# ('DE', 'Manure treatment (conventional), storage and land application')
# ('DE', 'Manure treatment (biogas), storage and land application')
# ('DE', 'Forestry, logging and related service activities (02)')
# ('DE', 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)')
# ('DE', 'Mining of coal and lignite; extraction of peat (10)')
# ('DE', 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying')
# ('DE', 'Extraction of natural gas and services related to natural gas extraction, excluding surveying')
# ('DE', 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials')
# ('DE', 'Mining of uranium and thorium ores (12)')
# ('DE', 'Mining of iron ores')
# ('DE', 'Mining of copper ores and concentrates')
# ('DE', 'Mining of nickel ores and concentrates')
# ('DE', 'Mining of aluminium ores and concentrates')
# ('DE', 'Mining of precious metal ores and concentrates')
# ('DE', 'Mining of lead, zinc and tin ores and concentrates')
# ('DE', 'Mining of other non-ferrous metal ores and concentrates')
# ('DE', 'Quarrying of stone')
# ('DE', 'Quarrying of sand and clay')
# ('DE', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('DE', 'Processing of meat cattle')
# ('DE', 'Processing of meat pigs')
# ('DE', 'Processing of meat poultry')
# ('DE', 'Production of meat products nec')
# ('DE', 'Processing vegetable oils and fats')
# ('DE', 'Processing of dairy products')
# ('DE', 'Processed rice')
# ('DE', 'Sugar refining')
# ('DE', 'Processing of Food products nec')
# ('DE', 'Manufacture of beverages')
# ('DE', 'Manufacture of fish products')
# ('DE', 'Manufacture of tobacco products (16)')
# ('DE', 'Manufacture of textiles (17)')
# ('DE', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('DE', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('DE', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('DE', 'Re-processing of secondary wood material into new wood material')
# ('DE', 'Pulp')
# ('DE', 'Re-processing of secondary paper into new pulp')
# ('DE', 'Paper')
# ('DE', 'Publishing, printing and reproduction of recorded media (22)')
# ('DE', 'Manufacture of coke oven products')
# ('DE', 'Petroleum Refinery')
# ('DE', 'Processing of nuclear fuel')
# ('DE', 'Plastics, basic')
# ('DE', 'Re-processing of secondary plastic into new plastic')
# ('DE', 'N-fertiliser')
# ('DE', 'P- and other fertiliser')
# ('DE', 'Chemicals nec')
# ('DE', 'Manufacture of rubber and plastic products (25)')
# ('DE', 'Manufacture of glass and glass products')
# ('DE', 'Re-processing of secondary glass into new glass')
# ('DE', 'Manufacture of ceramic goods')
# ('DE', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('DE', 'Manufacture of cement, lime and plaster')
# ('DE', 'Re-processing of ash into clinker')
# ('DE', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('DE', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('DE', 'Re-processing of secondary steel into new steel')
# ('DE', 'Precious metals production')
# ('DE', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('DE', 'Aluminium production')
# ('DE', 'Re-processing of secondary aluminium into new aluminium')
# ('DE', 'Lead, zinc and tin production')
# ('DE', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('DE', 'Copper production')
# ('DE', 'Re-processing of secondary copper into new copper')
# ('DE', 'Other non-ferrous metal production')
# ('DE', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('DE', 'Casting of metals')
# ('DE', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('DE', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('DE', 'Manufacture of office machinery and computers (30)')
# ('DE', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('DE', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('DE', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('DE', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('DE', 'Manufacture of other transport equipment (35)')
# ('DE', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('DE', 'Recycling of waste and scrap')
# ('DE', 'Recycling of bottles by direct reuse')
# ('DE', 'Production of electricity by coal')
# ('DE', 'Production of electricity by gas')
# ...
# ('WF', 'Mining of uranium and thorium ores (12)')
# ('WF', 'Mining of iron ores')
# ('WF', 'Mining of copper ores and concentrates')
# ('WF', 'Mining of nickel ores and concentrates')
# ('WF', 'Mining of aluminium ores and concentrates')
# ('WF', 'Mining of precious metal ores and concentrates')
# ('WF', 'Mining of lead, zinc and tin ores and concentrates')
# ('WF', 'Mining of other non-ferrous metal ores and concentrates')
# ('WF', 'Quarrying of stone')
# ('WF', 'Quarrying of sand and clay')
# ('WF', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('WF', 'Processing of meat cattle')
# ('WF', 'Processing of meat pigs')
# ('WF', 'Processing of meat poultry')
# ('WF', 'Production of meat products nec')
# ('WF', 'Processing vegetable oils and fats')
# ('WF', 'Processing of dairy products')
# ('WF', 'Processed rice')
# ('WF', 'Sugar refining')
# ('WF', 'Processing of Food products nec')
# ('WF', 'Manufacture of beverages')
# ('WF', 'Manufacture of fish products')
# ('WF', 'Manufacture of tobacco products (16)')
# ('WF', 'Manufacture of textiles (17)')
# ('WF', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('WF', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('WF', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('WF', 'Re-processing of secondary wood material into new wood material')
# ('WF', 'Pulp')
# ('WF', 'Re-processing of secondary paper into new pulp')
# ('WF', 'Paper')
# ('WF', 'Publishing, printing and reproduction of recorded media (22)')
# ('WF', 'Manufacture of coke oven products')
# ('WF', 'Petroleum Refinery')
# ('WF', 'Processing of nuclear fuel')
# ('WF', 'Plastics, basic')
# ('WF', 'Re-processing of secondary plastic into new plastic')
# ('WF', 'N-fertiliser')
# ('WF', 'P- and other fertiliser')
# ('WF', 'Chemicals nec')
# ('WF', 'Manufacture of rubber and plastic products (25)')
# ('WF', 'Manufacture of glass and glass products')
# ('WF', 'Re-processing of secondary glass into new glass')
# ('WF', 'Manufacture of ceramic goods')
# ('WF', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('WF', 'Manufacture of cement, lime and plaster')
# ('WF', 'Re-processing of ash into clinker')
# ('WF', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('WF', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('WF', 'Re-processing of secondary steel into new steel')
# ('WF', 'Precious metals production')
# ('WF', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('WF', 'Aluminium production')
# ('WF', 'Re-processing of secondary aluminium into new aluminium')
# ('WF', 'Lead, zinc and tin production')
# ('WF', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('WF', 'Copper production')
# ('WF', 'Re-processing of secondary copper into new copper')
# ('WF', 'Other non-ferrous metal production')
# ('WF', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('WF', 'Casting of metals')
# ('WF', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('WF', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('WF', 'Manufacture of office machinery and computers (30)')
# ('WF', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('WF', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('WF', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('WF', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('WF', 'Manufacture of other transport equipment (35)')
# ('WF', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('WF', 'Recycling of waste and scrap')
# ('WF', 'Recycling of bottles by direct reuse')
# ('WF', 'Production of electricity by coal')
# ('WF', 'Production of electricity by gas')
# ('WF', 'Production of electricity by nuclear')
# ('WF', 'Production of electricity by hydro')
# ('WF', 'Production of electricity by wind')
# ('WF', 'Production of electricity by petroleum and other oil derivatives')
# ('WF', 'Production of electricity by biomass and waste')
# ('WF', 'Production of electricity by solar photovoltaic')
# ('WF', 'Production of electricity by solar thermal')
# ('WF', 'Production of electricity by tide, wave, ocean')
# ('WF', 'Production of electricity by Geothermal')
# ('WF', 'Production of electricity nec')
# ('WF', 'Transmission of electricity')
# ('WF', 'Distribution and trade of electricity')
# ('WF', 'Manufacture of gas; distribution of gaseous fuels through mains')
# ('WF', 'Steam and hot water supply')
# ('WF', 'Collection, purification and distribution of water (41)')
# ('WF', 'Construction (45)')
# ('WF', 'Re-processing of secondary construction material into aggregates')
# ('WF', 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries')
# ('WF', 'Retail sale of automotive fuel')
# ('WF', 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)')
# ('WF', 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)')
# ('WF', 'Hotels and restaurants (55)')
# ('WF', 'Transport via railways')
# ('WF', 'Other land transport')
# ('WF', 'Transport via pipelines')
# ('WF', 'Sea and coastal water transport')
# ('WF', 'Inland water transport')
# ('WF', 'Air transport (62)')
# ('WF', 'Supporting and auxiliary transport activities; activities of travel agencies (63)')
# ('WF', 'Post and telecommunications (64)')
# ('WF', 'Financial intermediation, except insurance and pension funding (65)')
# ('WF', 'Insurance and pension funding, except compulsory social security (66)')
# ('WF', 'Activities auxiliary to financial intermediation (67)')
# ('WF', 'Real estate activities (70)')
# ('WF', 'Renting of machinery and equipment without operator and of personal and household goods (71)')
# ('WF', 'Computer and related activities (72)')
# ('WF', 'Research and development (73)')
# ('WF', 'Other business activities (74)')
# ('WF', 'Public administration and defence; compulsory social security (75)')
# ('WF', 'Education (80)')
# ('WF', 'Health and social work (85)')
# ('WF', 'Incineration of waste: Food')
# ('WF', 'Incineration of waste: Paper')
# ('WF', 'Incineration of waste: Plastic')
# ('WF', 'Incineration of waste: Metals and Inert materials')
# ('WF', 'Incineration of waste: Textiles')
# ('WF', 'Incineration of waste: Wood')
# ('WF', 'Incineration of waste: Oil/Hazardous waste')
# ('WF', 'Biogasification of food waste, incl. land application')
# ('WF', 'Biogasification of paper, incl. land application')
# ('WF', 'Biogasification of sewage slugde, incl. land application')
# ('WF', 'Composting of food waste, incl. land application')
# ('WF', 'Composting of paper and wood, incl. land application')
# ('WF', 'Waste water treatment, food')
# ('WF', 'Waste water treatment, other')
# ('WF', 'Landfill of waste: Food')
# ('WF', 'Landfill of waste: Paper')
# ('WF', 'Landfill of waste: Plastic')
# ('WF', 'Landfill of waste: Inert/metal/hazardous')
# ('WF', 'Landfill of waste: Textiles')
# ('WF', 'Landfill of waste: Wood')
# ('WF', 'Activities of membership organisation n.e.c. (91)')
# ('WF', 'Recreational, cultural and sporting activities (92)')
# ('WF', 'Other service activities (93)')
# ('WF', 'Private households with employed persons (95)')
# ('WF', 'Extra-territorial organizations and bodies')
# ('WM', 'Cultivation of paddy rice')
# ('WM', 'Cultivation of wheat')
# ('WM', 'Cultivation of cereal grains nec')
# ('WM', 'Cultivation of vegetables, fruit, nuts')
# ('WM', 'Cultivation of oil seeds')
# ('WM', 'Cultivation of sugar cane, sugar beet')
# ('WM', 'Cultivation of plant-based fibers')
# ('WM', 'Cultivation of crops nec')
# ('WM', 'Cattle farming')
# ('WM', 'Pigs farming')
# ('WM', 'Poultry farming')
# ('WM', 'Meat animals nec')
# ('WM', 'Animal products nec')
# ('WM', 'Raw milk')
# ('WM', 'Wool, silk-worm cocoons')
# ('WM', 'Manure treatment (conventional), storage and land application')
# ('WM', 'Manure treatment (biogas), storage and land application')
# ('WM', 'Forestry, logging and related service activities (02)')
# ('WM', 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)')
# ('WM', 'Mining of coal and lignite; extraction of peat (10)')
# ('WM', 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying')
# ('WM', 'Extraction of natural gas and services related to natural gas extraction, excluding surveying')
# ('WM', 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials')
# ('WM', 'Mining of uranium and thorium ores (12)')
# ('WM', 'Mining of iron ores')
# ('WM', 'Mining of copper ores and concentrates')
# ('WM', 'Mining of nickel ores and concentrates')
# ('WM', 'Mining of aluminium ores and concentrates')
# ('WM', 'Mining of precious metal ores and concentrates')
# ('WM', 'Mining of lead, zinc and tin ores and concentrates')
# ('WM', 'Mining of other non-ferrous metal ores and concentrates')
# ('WM', 'Quarrying of stone')
# ('WM', 'Quarrying of sand and clay')
# ('WM', 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.')
# ('WM', 'Processing of meat cattle')
# ('WM', 'Processing of meat pigs')
# ('WM', 'Processing of meat poultry')
# ('WM', 'Production of meat products nec')
# ('WM', 'Processing vegetable oils and fats')
# ('WM', 'Processing of dairy products')
# ('WM', 'Processed rice')
# ('WM', 'Sugar refining')
# ('WM', 'Processing of Food products nec')
# ('WM', 'Manufacture of beverages')
# ('WM', 'Manufacture of fish products')
# ('WM', 'Manufacture of tobacco products (16)')
# ('WM', 'Manufacture of textiles (17)')
# ('WM', 'Manufacture of wearing apparel; dressing and dyeing of fur (18)')
# ('WM', 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)')
# ('WM', 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)')
# ('WM', 'Re-processing of secondary wood material into new wood material')
# ('WM', 'Pulp')
# ('WM', 'Re-processing of secondary paper into new pulp')
# ('WM', 'Paper')
# ('WM', 'Publishing, printing and reproduction of recorded media (22)')
# ('WM', 'Manufacture of coke oven products')
# ('WM', 'Petroleum Refinery')
# ('WM', 'Processing of nuclear fuel')
# ('WM', 'Plastics, basic')
# ('WM', 'Re-processing of secondary plastic into new plastic')
# ('WM', 'N-fertiliser')
# ('WM', 'P- and other fertiliser')
# ('WM', 'Chemicals nec')
# ('WM', 'Manufacture of rubber and plastic products (25)')
# ('WM', 'Manufacture of glass and glass products')
# ('WM', 'Re-processing of secondary glass into new glass')
# ('WM', 'Manufacture of ceramic goods')
# ('WM', 'Manufacture of bricks, tiles and construction products, in baked clay')
# ('WM', 'Manufacture of cement, lime and plaster')
# ('WM', 'Re-processing of ash into clinker')
# ('WM', 'Manufacture of other non-metallic mineral products n.e.c.')
# ('WM', 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof')
# ('WM', 'Re-processing of secondary steel into new steel')
# ('WM', 'Precious metals production')
# ('WM', 'Re-processing of secondary preciuos metals into new preciuos metals')
# ('WM', 'Aluminium production')
# ('WM', 'Re-processing of secondary aluminium into new aluminium')
# ('WM', 'Lead, zinc and tin production')
# ('WM', 'Re-processing of secondary lead into new lead, zinc and tin')
# ('WM', 'Copper production')
# ('WM', 'Re-processing of secondary copper into new copper')
# ('WM', 'Other non-ferrous metal production')
# ('WM', 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals')
# ('WM', 'Casting of metals')
# ('WM', 'Manufacture of fabricated metal products, except machinery and equipment (28)')
# ('WM', 'Manufacture of machinery and equipment n.e.c. (29)')
# ('WM', 'Manufacture of office machinery and computers (30)')
# ('WM', 'Manufacture of electrical machinery and apparatus n.e.c. (31)')
# ('WM', 'Manufacture of radio, television and communication equipment and apparatus (32)')
# ('WM', 'Manufacture of medical, precision and optical instruments, watches and clocks (33)')
# ('WM', 'Manufacture of motor vehicles, trailers and semi-trailers (34)')
# ('WM', 'Manufacture of other transport equipment (35)')
# ('WM', 'Manufacture of furniture; manufacturing n.e.c. (36)')
# ('WM', 'Recycling of waste and scrap')
# ('WM', 'Recycling of bottles by direct reuse')
# ('WM', 'Production of electricity by coal')
# ('WM', 'Production of electricity by gas')
# ('WM', 'Production of electricity by nuclear')
# ('WM', 'Production of electricity by hydro')
# ('WM', 'Production of electricity by wind')
# ('WM', 'Production of electricity by petroleum and other oil derivatives')
# ('WM', 'Production of electricity by biomass and waste')
# ('WM', 'Production of electricity by solar photovoltaic')
# ('WM', 'Production of electricity by solar thermal')
# ('WM', 'Production of electricity by tide, wave, ocean')
# ('WM', 'Production of electricity by Geothermal')
# ('WM', 'Production of electricity nec')
# ('WM', 'Transmission of electricity')
# ('WM', 'Distribution and trade of electricity')
# ('WM', 'Manufacture of gas; distribution of gaseous fuels through mains')
# ('WM', 'Steam and hot water supply')
# ('WM', 'Collection, purification and distribution of water (41)')
# ('WM', 'Construction (45)')
# ('WM', 'Re-processing of secondary construction material into aggregates')
# ('WM', 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries')
# ('WM', 'Retail sale of automotive fuel')
# ('WM', 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)')
# ('WM', 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)')
# ('WM', 'Hotels and restaurants (55)')
# ('WM', 'Transport via railways')
# ('WM', 'Other land transport')
# ('WM', 'Transport via pipelines')
# ('WM', 'Sea and coastal water transport')
# ('WM', 'Inland water transport')
# ('WM', 'Air transport (62)')
# ('WM', 'Supporting and auxiliary transport activities; activities of travel agencies (63)')
# ('WM', 'Post and telecommunications (64)')
# ('WM', 'Financial intermediation, except insurance and pension funding (65)')
# ('WM', 'Insurance and pension funding, except compulsory social security (66)')
# ('WM', 'Activities auxiliary to financial intermediation (67)')
# ('WM', 'Real estate activities (70)')
# ('WM', 'Renting of machinery and equipment without operator and of personal and household goods (71)')
# ('WM', 'Computer and related activities (72)')
# ('WM', 'Research and development (73)')
# ('WM', 'Other business activities (74)')
# ('WM', 'Public administration and defence; compulsory social security (75)')
# ('WM', 'Education (80)')
# ('WM', 'Health and social work (85)')
# ('WM', 'Incineration of waste: Food')
# ('WM', 'Incineration of waste: Paper')
# ('WM', 'Incineration of waste: Plastic')
# ('WM', 'Incineration of waste: Metals and Inert materials')
# ('WM', 'Incineration of waste: Textiles')
# ('WM', 'Incineration of waste: Wood')
# ('WM', 'Incineration of waste: Oil/Hazardous waste')
# ('WM', 'Biogasification of food waste, incl. land application')
# ('WM', 'Biogasification of paper, incl. land application')
# ('WM', 'Biogasification of sewage slugde, incl. land application')
# ('WM', 'Composting of food waste, incl. land application')
# ('WM', 'Composting of paper and wood, incl. land application')
# ('WM', 'Waste water treatment, food')
# ('WM', 'Waste water treatment, other')
# ('WM', 'Landfill of waste: Food')
# ('WM', 'Landfill of waste: Paper')
# ('WM', 'Landfill of waste: Plastic')
# ('WM', 'Landfill of waste: Inert/metal/hazardous')
# ('WM', 'Landfill of waste: Textiles')
# ('WM', 'Landfill of waste: Wood')
# ('WM', 'Activities of membership organisation n.e.c. (91)')
# ('WM', 'Recreational, cultural and sporting activities (92)')
# ('WM', 'Other service activities (93)')
# ('WM', 'Private households with employed persons (95)')
# ('WM', 'Extra-territorial organizations and bodies')

# %% [markdown]
# ## Question 1: Carbon footprint of the nations (18 points)

# %% [markdown]
# #### 1.1 What were the per capita carbon footprint of each of the 49 exiobase regions when considering only CO2 emissions in 2015? (8 points)

# %%
# Import population data
population = pd.read_excel('data/exiobase_PopulationGDP_1995_2019.xlsx',sheet_name='Population', index_col=[0, 1, 2])
pop2015 = population.loc[:,"y2015"]

# %%
# Calculate the rest of MRIO variables
I = np.identity(A.shape[0])
L = np.linalg.inv(I-A)
x = L @ Y.sum(axis=1)

# %%
x_ = x.copy()
x_[x_!=0] = 1/x_[x_!=0]
inv_diag_x_ = np.diag(x_)

# %%
# CO2 Extensions 
F_sat_CO2 = F_sat[F_sat.index.str.contains("CO2")].sum(axis=0)
F_sat_hh_CO2 = F_sat_hh[F_sat_hh.index.str.contains("CO2")].sum(axis=0)

# %% [markdown]
# by running the following
#
# F_sat_hh.index.str.contains("CO2")
#
# You are obtaining a boolean array (i.e., an array of true and false values), where true is assigned to the position of all labels that contain "CO2" in them.
#
# This is the equivalent of creating a list of all the labels concerning CO2 emissions in the extension such as
#
# ```
# ['CO2 - combustion - air',
# 'CO2 - non combustion - Cement production - air',
# 'CO2 - non combustion - Lime production - air',
# 'CO2 - agriculture - peat decay - air',
# 'CO2 - waste - biogenic - air', 'CO2 - waste - fossil - air']
# ```
#
# ##### Explanation
#
# **F_sat_gg.index** returns all labels of your index
#
# **.str** allows to treat each entry of the index as a string
#
# **.contains()** is a method for strings that allows you check whether a string may contain another string

# %%
# CO2 Intensities
f_sat_CO2 = F_sat_CO2 @ inv_diag_x_

# %%
# Aggregate Y by region
Y_reg = Y.groupby(level=0, axis=1, sort=False).sum()

# %%
# Aggregate F_sat_hh by region
F_sat_hh_CO2_reg = F_sat_hh_CO2.groupby(level=0, sort=False).sum()

# %%
# Footprint calculation
e_CO2 = f_sat_CO2 @ L @ Y_reg + F_sat_hh_CO2_reg
e_CO2_pp = e_CO2/pop2015.values/1000 #convert the unit from kg to metric ton/capita

e_CO2_pp
# Out:
# region
# AT     9.811567
# BE    11.808848
# BG     5.072057
# CY     9.815370
# CZ     9.619117
# DE    11.598026
# DK    11.675322
# EE    11.375827
# ES     6.256477
# FI    10.289243
# FR     6.922484
# GR    12.511011
# HR     3.992216
# HU     5.451145
# IE    11.723657
# IT     7.667742
# LT     6.752614
# LU    23.166439
# LV     6.043555
# MT    12.926639
# NL    12.321761
# PL     7.399379
# PT     5.492885
# RO     3.829157
# SE     7.183384
# SI     7.526126
# SK     7.693971
# GB     9.769436
# US    18.518329
# JP    10.047756
# CN     6.435537
# CA    14.149816
# KR    12.219827
# BR     2.466260
# IN     1.629168
# MX     3.494032
# RU     7.964158
# AU    18.637680
# CH    11.225801
# TR     5.136483
# TW     6.871530
# NO    13.540860
# ID     1.843218
# ZA     5.566805
# WA     2.064527
# WL     3.585200
# WE     3.846268
# WF     0.859331
# WM     6.512545
# dtype: float64

# %%
# Other method to aggregate results instead of groupby
# 1st collect the labels (r=number of regions; s=number of sectors)
Y_labels = Y.index.to_frame(index=None)
region_labels = Y_labels.region.drop_duplicates().reset_index(drop=True)
sector_labels = Y_labels.sector.drop_duplicates().reset_index(drop=True)
r = region_labels.shape[0]
s = sector_labels.shape[0]

# %%
# Create empty arrays of the desired shape/order
Yt = np.zeros((r*s,r))
F1_hht = np.zeros((F_sat_hh.shape[0],r))

# %%
# Aggregate Y and F_hh

for l in region_labels.items(): 
    Yt[:,l[0]]=Y.loc[:,l[1]].sum(axis=1)
    F1_hht[:,l[0]]=F_sat_hh.loc[:,l[1]].sum(axis=1)

# %%
np.allclose(Yt.sum(axis=0), Y_reg.sum(axis=0))
# Out:
# True

# %% [markdown]
# #### 1.2 What were the per capita carbon footprint of each of the 49 regions in CO2e when considering CH4, N2O, and CO2? (6 points)
# Instruction: Please use 29.8 and 273 for GWP100 of CH4 and N2O, respectively.

# %%
F_sat_CO2 = F_sat[F_sat.index.str.contains("CO2")].sum(axis=0)
F_sat_CH4 = F_sat[F_sat.index.str.contains("CH4")].sum(axis=0)*29.8
F_sat_N2O = F_sat[F_sat.index.str.contains("N2O")].sum(axis=0)*273

F_GHG_ = pd.concat([F_sat_CO2, F_sat_CH4, F_sat_N2O],axis=1).T
F_GHG_.index = ["CO2", "CH4", "N2O"]
F_GHG_
# Out:
# region                        AT                       \
# sector Cultivation of paddy rice Cultivation of wheat
# CO2                          0.0         2.290468e+08
# CH4                          0.0         3.193777e+05
# N2O                          0.0         2.788491e+08
#
# region                                   \
# sector Cultivation of cereal grains nec
# CO2                        2.359974e+08
# CH4                        4.474301e+05
# N2O                        4.180574e+08
#
# region                                                                  \
# sector Cultivation of vegetables, fruit, nuts Cultivation of oil seeds
# CO2                              9.388639e+07             4.644045e+07
# CH4                              2.838360e+05             1.270425e+05
# N2O                              9.107078e+07             1.288437e+08
#
# region                                        \
# sector Cultivation of sugar cane, sugar beet
# CO2                             1.408942e+07
# CH4                             4.745501e+04
# N2O                             4.933941e+07
#
# region                                                             \
# sector Cultivation of plant-based fibers Cultivation of crops nec
# CO2                         39418.948028             1.808811e+06
# CH4                           136.651618             1.656764e+04
# N2O                        450938.409455             4.648129e+06
#
# region                               ...                       WM  \
# sector Cattle farming  Pigs farming  ... Landfill of waste: Paper
# CO2      1.886045e+08  6.049997e+07  ...             5.266399e+07
# CH4      2.651895e+09  1.441410e+08  ...             4.759316e+10
# N2O      5.799846e+08  1.647127e+08  ...             4.897483e+04
#
# region                                                                      \
# sector Landfill of waste: Plastic Landfill of waste: Inert/metal/hazardous
# CO2                  4.062944e+07                             5.042184e+07
# CH4                  1.436608e+09                             3.059326e+07
# N2O                  2.444897e+04                             5.636156e+04
#
# region                                                      \
# sector Landfill of waste: Textiles Landfill of waste: Wood
# CO2                   3.842686e+07            5.549526e+07
# CH4                   6.331344e+09            1.399794e+09
# N2O                   1.457448e+04            1.970197e+04
#
# region                                                    \
# sector Activities of membership organisation n.e.c. (91)
# CO2                                         2.129266e+08
# CH4                                         2.671610e+06
# N2O                                         3.448882e+05
#
# region                                                      \
# sector Recreational, cultural and sporting activities (92)
# CO2                                          4.679020e+08
# CH4                                          5.699469e+06
# N2O                                          8.085240e+05
#
# region                                \
# sector Other service activities (93)
# CO2                     3.349103e+08
# CH4                     3.227710e+06
# N2O                     7.122501e+05
#
# region                                                \
# sector Private households with employed persons (95)
# CO2                                     6.326304e+07
# CH4                                     9.343112e+05
# N2O                                     1.045804e+05
#
# region
# sector Extra-territorial organizations and bodies
# CO2                                           0.0
# CH4                                           0.0
# N2O                                           0.0
#
# [3 rows x 7987 columns]

# %%
# Intensities satellite
f_GHG = F_GHG_ @ inv_diag_x_ 
f_GHG
# Out:
#      0              1              2             3              4     \
# CO2   0.0  691259.800152  310277.849577  66286.364256  316544.074316
# CH4   0.0     963.876994     588.259219    200.395987     865.938182
# N2O   0.0  841562.290311  549641.469482  64298.463925  878215.055451
#
#               5              6             7             8              9     \
# CO2  167373.122947   26977.557519   5761.174473  3.834245e+05   73824.712479
# CH4     563.734657      93.521696     52.768967  5.391183e+06  175887.120618
# N2O  586120.113971  308613.433066  14804.579548  1.179082e+06  200989.676186
#
#      ...          7977          7978          7979          7980  \
# CO2  ...  3.158695e+04  4.388930e+04  28723.374473  8.355061e+04
# CH4  ...  2.854555e+07  1.551873e+06  17427.794623  1.376609e+07
# N2O  ...  2.937425e+01  2.641061e+01     32.107002  3.168894e+01
#
#              7981          7982          7983          7984          7985  \
# CO2  9.429815e+04  14226.117991  10278.420127  13103.352764  10560.562008
# CH4  2.378545e+06    178.496429    125.200438    126.284045    155.965490
# N2O  3.347781e+01     23.042775     17.760877     27.866759     17.457712
#
#      7986
# CO2   0.0
# CH4   0.0
# N2O   0.0
#
# [3 rows x 7987 columns]

# %%
# Households satellites
F_sat_hh_CO2 = F_sat_hh[F_sat_hh.index.str.contains("CO2")].sum(axis=0)
F_sat_hh_CH4 = F_sat_hh[F_sat_hh.index.str.contains("CH4")].sum(axis=0)*29.8
F_sat_hh_N2O = F_sat_hh[F_sat_hh.index.str.contains("N2O")].sum(axis=0)*273

F_hh_GHG_ = pd.concat([F_sat_hh_CO2, F_sat_hh_CH4, F_sat_hh_N2O],axis=1).T
F_hh_GHG_.index = ["CO2", "CH4", "N2O"]

# Aggregate F_sat_hh by region
F_hh_GHG_reg = F_hh_GHG_.groupby(level=0, axis=1, sort=False).sum()

F_hh_GHG_reg
# Out:
# region            AT            BE            BG            CY            CZ  \
# CO2     1.649435e+10  2.346101e+10  4.402743e+09  1.488962e+09  1.120496e+10
# CH4     4.648808e+08  9.236450e+07  2.681356e+08  1.941141e+06  7.526603e+08
# N2O     2.168365e+08  1.790871e+08  2.476122e+07  6.664511e+06  2.289607e+08
#
# region            DE            DK            EE            ES            FI  \
# CO2     2.021225e+11  8.171912e+09  7.055757e+08  6.308866e+10  5.450621e+09
# CH4     1.179378e+09  2.794978e+08  7.700563e+07  4.143630e+08  4.219064e+08
# N2O     5.400237e+08  7.758891e+07  8.145946e+06  7.992618e+08  1.591878e+08
#
# region  ...            TR            TW            NO            ID  \
# CO2     ...  4.498783e+10  2.006928e+10  3.764177e+09  6.478355e+10
# CH4     ...  6.013385e+08  3.100029e+07  4.091918e+07  1.766731e+10
# N2O     ...  6.726210e+08  8.239212e+07  5.554300e+07  2.960401e+09
#
# region            ZA            WA            WL            WE            WF  \
# CO2     4.836168e+10  2.564473e+11  1.732998e+11  3.611237e+10  2.639215e+11
# CH4     4.893146e+09  3.051683e+10  6.172756e+09  9.216313e+08  1.005692e+11
# N2O     9.064638e+08  9.754589e+09  2.938656e+09  6.890047e+08  1.409893e+10
#
# region            WM
# CO2     3.301295e+11
# CH4     4.641123e+08
# N2O     1.466206e+09
#
# [3 rows x 49 columns]

# %%
# Footprint calculation
e_CO2 = f_GHG.loc["CO2"] @ L @ Y_reg + F_hh_GHG_reg.loc["CO2"]
e_CH4 = f_GHG.loc["CH4"] @ L @ Y_reg + F_hh_GHG_reg.loc["CH4"]
e_N2O = f_GHG.loc["N2O"] @ L @ Y_reg + F_hh_GHG_reg.loc["N2O"]

e_CO2eq = e_CO2 + e_CH4 + e_N2O

# CO2_eq per capita
e_CO2eq_pp = e_CO2eq/pop2015.values/1000 #convert the unit from kg to metric ton/capita

e_CO2eq_pp
# Out:
# region
# AT    12.756943
# BE    15.889312
# BG     7.072497
# CY    11.636641
# CZ    12.200267
# DE    14.368607
# DK    14.688278
# EE    15.041655
# ES     8.635758
# FI    15.034909
# FR     9.628982
# GR    14.943025
# HR     5.912843
# HU     7.474584
# IE    18.097559
# IT    10.461834
# LT     9.920193
# LU    35.721233
# LV     8.968882
# MT    17.744231
# NL    16.539988
# PL     9.823864
# PT     7.945518
# RO     5.568849
# SE    10.085219
# SI    10.782638
# SK    10.789558
# GB    13.476931
# US    22.644429
# JP    11.901278
# CN     8.036088
# CA    18.070868
# KR    15.049373
# BR     5.494303
# IN     2.603776
# MX     5.076482
# RU    10.337273
# AU    26.364487
# CH    14.816107
# TR     7.262026
# TW     9.246116
# NO    18.087145
# ID     3.342023
# ZA     6.989603
# WA     3.198766
# WL     5.725800
# WE     6.077016
# WF     2.308441
# WM     8.233952
# dtype: float64

# %% [markdown]
# #### 1.3 What is the proportion of CO2 emissions in CO2e in each region's carbon footprint measured in CO2e? (4 points)

# %%
# Proportion of CO2 emissions to GWP by country
e_GWP = e_CO2 + e_CH4 + e_N2O
CO2_to_CO2eq = e_CO2/e_GWP * 100

CO2_to_CO2eq, CO2_to_CO2eq.max(), CO2_to_CO2eq.min()
# Out:
# (region
#  AT    76.911585
#  BE    74.319444
#  BG    71.715219
#  CY    84.348826
#  CZ    78.843490
#  DE    80.717822
#  DK    79.487342
#  EE    75.628829
#  ES    72.448500
#  FI    68.435687
#  FR    71.892165
#  GR    83.724753
#  HR    67.517701
#  HU    72.929075
#  IE    64.780323
#  IT    73.292521
#  LT    68.069377
#  LU    64.853413
#  LV    67.383587
#  MT    72.849815
#  NL    74.496797
#  PL    75.320452
#  PT    69.131867
#  RO    68.760287
#  SE    71.226852
#  SI    69.798565
#  SK    71.309414
#  GB    72.490066
#  US    81.778739
#  JP    84.425858
#  CN    80.082957
#  CA    78.301802
#  KR    81.198245
#  BR    44.887583
#  IN    62.569440
#  MX    68.827817
#  RU    77.043127
#  AU    70.692367
#  CH    75.767547
#  TR    70.730723
#  TW    74.318011
#  NO    74.864554
#  ID    55.152768
#  ZA    79.644091
#  WA    64.541373
#  WL    62.614838
#  WE    63.292054
#  WF    37.225620
#  WM    79.093796
#  dtype: float64,
#  84.42585759260712,
#  37.22561994383321)

# %% [markdown]
# Double click on this cell to write your answer. Run the cell (ctrl+enter) once you are done writing so that it saves your input

# %% [markdown]
# ## Question 2: Territorial emissions (6 points)

# %% [markdown]
# #### 2.1 What were the per capita territorial emissions of the US and China, respectively, in 2015? Only consider CO2 emissions here. (6 points)

# %%
e_CO2_pba = np.diag(f_sat_CO2) @ x
e_CO2_pba = e_CO2_pba.reshape(r,s).sum(1) + F_sat_hh_CO2_reg

e_CO2_pba_pp = e_CO2_pba/pop2015.values/1000 #convert unit from kg to tonne/capita

e_CO2_pba_pp.loc[["US","CN"]]
# Out:
# region
# US    15.955813
# CN     7.315289
# dtype: float64

# %% [markdown]
# ## Question 3: Emissions embodied in trade (20 points)

# %% [markdown]
# #### 3.1 Were the US and China net importers or exporters of CO2 emissions in 2015? (4 points)

# %%
net_import = (e_CO2 - e_CO2_pba)*1e-9 # convert from kg to million metric ton
net_import.loc[["US","CN"]]
# Out:
# region
# US     826.367883
# CN   -1194.159021
# dtype: float64

# %% [markdown]
# Double click on this cell to write your answer. Run the cell (ctrl+enter) once you are done writing so that it saves your input

# %% [markdown]
# #### 3.2 Which were the top three regional contributers of US' and China's carbon footprints (only consider CO2 emissions), respectively, in 2015? (12 points)

# %%
e_CO2_cont = np.diag(f_sat_CO2) @ L @ Y_reg
e_CO2_US = e_CO2_cont.loc[:, "US"]
e_CO2_CN = e_CO2_cont.loc[:, "CN"]

e_CO2_US.index = Y.index
e_CO2_CN.index = Y.index

# print(e_CO2_US.groupby(level=0).sum().nlargest(n=3))
# print(e_CO2_CN.groupby(level=0).sum().nlargest(n=3))

print(e_CO2_US.groupby(level=0).sum().sort_values(ascending=False)[:3])
print(e_CO2_CN.groupby(level=0).sum().sort_values(ascending=False)[:3])
# Out:
# region
# US    3.195043e+12
# CN    3.970129e+11
# CA    1.344926e+11
# Name: US, dtype: float64
# region
# CN    7.495721e+12
# WA    1.824185e+11
# WM    9.450926e+10
# Name: CN, dtype: float64

# %% [markdown]
# #### 3.3 By conducting emissions embodied in trade calculations, how much CO2 emissions did the US outsourced to China in 2015? (4 points)

# %%
e_CO2_US_to_CN = e_CO2_US.loc["CN"].sum() - e_CO2_CN.loc["US"].sum()
e_CO2_US_to_CN * 1e-9
# Out:
# 338.84369064912204

# %% [markdown]
# The net outsourcing of CO2 emissions by the US to China in 2015 was 338.8 Mt CO2

# %% [markdown]
# ## Question 4 Environmental vs Economic Footprints Analysis (16 points)

# %% [markdown]
# #### 4.1 Using the "impact" accounts, what were the value added footrpints of the US and China, respectively, in 2015? (8 points)

# %%
# Import impact accounts
F_imp = pd.read_csv(f'{path}impacts/F.txt' , sep='\t', index_col=[0], header=[0, 1])
F_imp_hh = pd.read_csv(f'{path}impacts/F_y.txt' , sep='\t', index_col=[0], header=[0, 1])

# %%
# VA coefficients
VA = F_imp[F_imp.index.str.contains("Value Added")]
f_VA = VA.values @ inv_diag_x_
e_VA = f_VA @ L @ Y_reg

e_VA_pp = e_VA/pop2015.values*1e6 

e_VA_pp.loc[:, ["US", "CN"]]
# Out:
# region            US           CN
# 0       52445.887193  7107.782845

# %% [markdown]
# #### 4.2 Make two main observations on the carbon vs value added footprint results regarding the relationships between the US and China? Please refer to the carbon footprint results obtained in Question 1 (8 points)

# %% [markdown]
# Double click on this cell to write your answer. Run the cell (ctrl+enter) once you are done writing so that it saves your input
